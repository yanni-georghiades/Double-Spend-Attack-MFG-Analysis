# %%
import numpy as np
from matplotlib import pyplot as plt
import pickle
from matplotlib import cm
import itertools

# %%
def open_file(filename):
    try:
        with open(filename, "rb") as f:
            experiment = pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
    return experiment

def exp_info(experiment):
    
    print("Experiment Information:")
    print("=" * 20)
    print("k: " + str(experiment.k))
    print("beta: " + str(experiment.beta))
    print("block reward: " + str(experiment.block_reward))
    print("alpha bar init: " + str(experiment.alpha_bar_init))
    print("mining cost: " + str(experiment.mining_cost))
    print("number of agents: " + str(experiment.num_agents))
    print("max wealth: " + str(experiment.max_wealth))
    print("max z: " + str(experiment.max_tx_value))
    print("T: " + str(experiment.T))
    print("N: " + str(experiment.N))
    print("momentum: " + str(experiment.momentum))

# %%
plt.figure(figsize=(10,10))

g10 = open_file('fdata/g10.pickle')

# average wealth perceived vs actual
last_wealths = g10.WEALTH_HISTORY[-1]
avgs = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs.append(avg)
    
plt.plot(avgs, 'r-', label='perceived; b=10')

# g125 = open_file('fdata/g125.pickle')

# # average wealth perceived vs actual
# last_wealths = g125.WEALTH_HISTORY[-1]
# avgs = []
# for last_wealth in last_wealths:
#     avg = 0
#     for i in range(len(last_wealth)):
#         avg += i * last_wealth[i]
#     avgs.append(avg)
    
# plt.plot(avgs, 'b--', label='perceived; b=12.5')

g15 = open_file('fdata/g15.pickle')

# average wealth perceived vs actual
last_wealths = g15.WEALTH_HISTORY[-1]
avgs = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs.append(avg)
    
plt.plot(avgs, 'r--', label='perceived; b=15')
# g175 = open_file('fdata/g175.pickle')

# # average wealth perceived vs actual
# last_wealths = g175.WEALTH_HISTORY[-1]
# avgs = []
# for last_wealth in last_wealths:
#     avg = 0
#     for i in range(len(last_wealth)):
#         avg += i * last_wealth[i]
#     avgs.append(avg)
    
# plt.plot(avgs, 'r--', label='perceived; b=17.5')

a10 = open_file('fdata/a10.pickle')

# average wealth perceived vs actual
last_wealths = a10.WEALTH_HISTORY[-1]
avgs = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs.append(avg)
    
plt.plot(avgs, 'b-', label='actual; b=10')

# a125 = open_file('fdata/a125.pickle')

# # average wealth perceived vs actual
# last_wealths = a125.WEALTH_HISTORY[-1]
# avgs = []
# for last_wealth in last_wealths:
#     avg = 0
#     for i in range(len(last_wealth)):
#         avg += i * last_wealth[i]
#     avgs.append(avg)
    
# plt.plot(avgs, 'b-', label='actual; b=12.5')

a15 = open_file('fdata/a15.pickle')

# average wealth perceived vs actual
last_wealths = a15.WEALTH_HISTORY[-1]
avgs = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs.append(avg)
    
plt.plot(avgs, 'b--', label='actual; b=15')
# a175 = open_file('fdata/a175.pickle')

# # average wealth perceived vs actual
# last_wealths = a175.WEALTH_HISTORY[-1]
# avgs = []
# for last_wealth in last_wealths:
#     avg = 0
#     for i in range(len(last_wealth)):
#         avg += i * last_wealth[i]
#     avgs.append(avg)
    
# plt.plot(avgs, 'r-', label='actual; b=17.5')

plt.title('Average Wealth vs Time')
plt.xlabel('Time')
plt.ylabel('Average Wealth')
plt.legend()

# %%
fig, axs = plt.subplots(1, 3, figsize=(17,5))

# g10 = open_file('fdata/g10.pickle')

# # average wealth perceived vs actual
# last_wealths = g10.WEALTH_HISTORY[-1]
# avgs = []
# for last_wealth in last_wealths:
#     avg = 0
#     for i in range(len(last_wealth)):
#         avg += i * last_wealth[i]
#     avgs.append(avg)
    
# axs[0].plot(avgs, 'r-', label='perceived; b=10')
# axs[1].plot(g10.ATTACK_HISTORY[-1], 'r-', label='perceived; b=10')
# axs[2].plot(g10.ALPHA_BAR_HISTORY[-1], 'r-', label='perceived; b=10')

g125 = open_file('fdata/g125.pickle')

# average wealth perceived vs actual
last_wealths = g125.WEALTH_HISTORY[-1]
avgs = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs.append(avg)
    
axs[0].plot(avgs, 'r-', label='perceived; b=12.5')
axs[1].plot(g125.ATTACK_HISTORY[-1], 'r-', label='perceived; b=12.5')
axs[2].plot(g125.ALPHA_BAR_HISTORY[-1], 'r-', label='perceived; b=12.5')


g15 = open_file('fdata/g15.pickle')

# average wealth perceived vs actual
last_wealths = g15.WEALTH_HISTORY[-1]
avgs = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs.append(avg)
    
axs[0].plot(avgs, 'r--', label='perceived; b=15')
axs[1].plot(g15.ATTACK_HISTORY[-1], 'r--', label='perceived; b=15')
axs[2].plot(g15.ALPHA_BAR_HISTORY[-1], 'r--', label='perceived; b=15')

g175 = open_file('fdata/g175.pickle')

# average wealth perceived vs actual
last_wealths = g175.WEALTH_HISTORY[-1]
avgs = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs.append(avg)
    
axs[0].plot(avgs, 'r:', label='perceived; b=17.5')
axs[1].plot(g175.ATTACK_HISTORY[-1], 'r:', label='perceived; b=17.5')
axs[2].plot(g175.ALPHA_BAR_HISTORY[-1], 'r:', label='perceived; b=17.5')

# a10 = open_file('fdata/a10.pickle')

# # average wealth perceived vs actual
# last_wealths = a10.WEALTH_HISTORY[-1]
# avgs = []
# for last_wealth in last_wealths:
#     avg = 0
#     for i in range(len(last_wealth)):
#         avg += i * last_wealth[i]
#     avgs.append(avg)
    
# axs[0].plot(avgs, 'b-', label='actual; b=10')

a125 = open_file('fdata/a125.pickle')

# average wealth perceived vs actual
last_wealths = a125.WEALTH_HISTORY[-1]
avgs = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs.append(avg)
    
axs[0].plot(avgs, 'b-', label='actual; b=12.5')
axs[1].plot(a125.ATTACK_HISTORY[-1], 'b-', label='actual; b=12.5')
axs[2].plot(a125.ALPHA_BAR_HISTORY[-1], 'b-', label='actual; b=12.5')


a15 = open_file('fdata/a15.pickle')

# average wealth perceived vs actual
last_wealths = a15.WEALTH_HISTORY[-1]
avgs = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs.append(avg)
    
axs[0].plot(avgs, 'b--', label='actual; b=15')
axs[1].plot(a15.ATTACK_HISTORY[-1], 'b--', label='actual; b=15')
axs[2].plot(a15.ALPHA_BAR_HISTORY[-1], 'b--', label='actual; b=15')


a175 = open_file('fdata/a175.pickle')

# average wealth perceived vs actual
last_wealths = a175.WEALTH_HISTORY[-1]
avgs = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs.append(avg)
    
axs[0].plot(avgs, 'b:', label='actual; b=17.5')
axs[1].plot(a175.ATTACK_HISTORY[-1], 'b:', label='actual; b=17.5')
axs[2].plot(a175.ALPHA_BAR_HISTORY[-1], 'b:', label='actual; b=17.5')




axs[0].set(xlabel='Time', ylabel='Average Wealth')
axs[0].set_title('Average Wealth vs Time')
axs[0].legend()

axs[1].set(xlabel='Time', ylabel='Attack Probability')
axs[1].set_title('Adversary Attack Probability vs Time')
axs[1].legend()

axs[2].set(xlabel='Time', ylabel='Mean Alpha')
axs[2].set_title('Mean Alpha vs Time')
axs[2].legend()

# %%
wealth = a15.WEALTH_HISTORY[-1]
color = iter(cm.rainbow(np.linspace(0, 1, len(wealth))))
for i in range(len(wealth)):
    w = wealth[i]
    c = next(color)
    plt.plot(w, c=c, label='t=' + str(i))
# axs[1,0].set_title("Wealth Evolution in Final Iteration")
# axs[1,0].set(xlabel='Wealth', ylabel='Proportion of Miners')
plt.title("Wealth Distribution vs Time")
plt.xlabel('Wealth')
plt.ylabel('Fraction of Miners')
plt.legend()

# %%
# mining performance vs adv strength actual
a0 = open_file('data1/0a.pickle')
a1 = open_file('data1/1a.pickle')
a2 = open_file('data1/2a.pickle')
a3 = open_file('data1/35a.pickle')
a4 = open_file('data1/45a.pickle')


last_wealths = a0.WEALTH_HISTORY[-1]
avgs0 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs0.append(avg)
    
last_wealths = a1.WEALTH_HISTORY[-1]
avgs1 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs1.append(avg)

last_wealths = a2.WEALTH_HISTORY[-1]
avgs2 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs2.append(avg)
    
last_wealths = a3.WEALTH_HISTORY[-1]
avgs3 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs3.append(avg)
    
last_wealths = a4.WEALTH_HISTORY[-1]
avgs4 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs4.append(avg)
    
    
# plt.plot(avgs0, '--', label='beta=0')
plt.plot(avgs1, '-.', label='beta=.1')
plt.plot(avgs2, ':', label='beta=.2')
plt.plot(avgs3, '--', label='beta=.35')
plt.plot(avgs4, '-', label='beta=.45')
plt.legend()
plt.title("Mining Performance with Knowledge of Adversary")
plt.xlabel('Time')
plt.ylabel('Wealth')
# Out:
# Text(0, 0.5, 'Wealth')

# %%
# mining performance vs adv strength perceived
a0 = open_file('data2/0a.pickle')
a1 = open_file('data2/1a.pickle')
a2 = open_file('data2/2a.pickle')
a3 = open_file('data2/35a.pickle')
a4 = open_file('data2/45a.pickle')


last_wealths = a0.WEALTH_HISTORY[-1]
avgs0 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs0.append(avg)
    
last_wealths = a1.WEALTH_HISTORY[-1]
avgs1 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs1.append(avg)

last_wealths = a2.WEALTH_HISTORY[-1]
avgs2 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs2.append(avg)
    
last_wealths = a3.WEALTH_HISTORY[-1]
avgs3 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs3.append(avg)
    
last_wealths = a4.WEALTH_HISTORY[-1]
avgs4 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs4.append(avg)
    
    
# plt.plot(avgs0, '--', label='beta=0')
plt.plot(avgs1, '-.', label='beta=.1')
plt.plot(avgs2, ':', label='beta=.2')
plt.plot(avgs3, '--', label='beta=.35')
plt.plot(avgs4, '-', label='beta=.45')
plt.legend()
plt.title("Mining Performance without Knowledge of Adversary")
plt.xlabel('Time')
plt.ylabel('Wealth')
# Out:
# Text(0, 0.5, 'Wealth')

# %%
# attack prob vs time with adversary knowledge
a0 = open_file('data1/0a.pickle')
a1 = open_file('data1/1a.pickle')
a2 = open_file('data1/2a.pickle')
a3 = open_file('data1/35a.pickle')
a4 = open_file('data1/45a.pickle')


atks0 = a0.ATTACK_HISTORY[-1]
    
atks1 = a1.ATTACK_HISTORY[-1]

atks2 = a2.ATTACK_HISTORY[-1]

atks3 = a3.ATTACK_HISTORY[-1]

atks4 = a4.ATTACK_HISTORY[-1]

    
# plt.plot(atks0, '--', label='beta=0')
plt.ylim([-0.1,1.1])
plt.plot(atks1, '-.', label='beta=.1')
plt.plot(atks2, ':', label='beta=.2')
plt.plot(atks3, '--', label='beta=.35')
plt.plot(atks4, '-', label='beta=.45')
plt.legend()
plt.title("Attack Probability vs Time with Knowledge of Adversary")
plt.xlabel('Time')
plt.ylabel('Attack Probability')
# Out:
# Text(0, 0.5, 'Attack Probability')

# %%
# tx value vs time with adversary knowledge
a0 = open_file('data1/0a.pickle')
a1 = open_file('data1/1a.pickle')
a2 = open_file('data1/2a.pickle')
a3 = open_file('data1/35a.pickle')
a4 = open_file('data1/45a.pickle')


zs1 = []
for zw, ww in zip(a1.Z_HISTORY[-1], a1.WEALTH_HISTORY[-1]):
    avg = 0
    for z, w in zip(zw, ww):
        avg += z*w

    zs1.append(avg)

    
zs2 = []
for zw, ww in zip(a2.Z_HISTORY[-1], a2.WEALTH_HISTORY[-1]):
    avg = 0
    for z, w in zip(zw, ww):
        avg += z*w

    zs2.append(avg)

zs3 = []
for zw, ww in zip(a3.Z_HISTORY[-1], a3.WEALTH_HISTORY[-1]):
    avg = 0
    for z, w in zip(zw, ww):
        avg += z*w

    zs3.append(avg)
    
    
zs4 = []
for zw, ww in zip(a4.Z_HISTORY[-1], a4.WEALTH_HISTORY[-1]):
    avg = 0
    for z, w in zip(zw, ww):
        avg += z*w

    zs4.append(avg)
    
    
    
# plt.plot(atks0, '--', label='beta=0')
plt.plot(zs1, '-.', label='beta=.1')
plt.plot(zs2, ':', label='beta=.2')
plt.plot(zs3, '--', label='beta=.35')
plt.plot(zs4, '-', label='beta=.45')
plt.legend()
plt.title("Transaction Value vs Time with Knowledge of Adversary")
plt.xlabel('Time')
plt.ylabel('Transaction Value')
# Out:
# Text(0, 0.5, 'Transaction Value')

# %%
# tx value vs time with adversary knowledge
a0 = open_file('data2/0a.pickle')
a1 = open_file('data2/1a.pickle')
a2 = open_file('data2/2a.pickle')
a3 = open_file('data2/35a.pickle')
a4 = open_file('data2/45a.pickle')


zs1 = []
for zw, ww in zip(a1.Z_HISTORY[-1], a1.WEALTH_HISTORY[-1]):
    avg = 0
    for z, w in zip(zw, ww):
        avg += z*w

    zs1.append(avg)

    
zs2 = []
for zw, ww in zip(a2.Z_HISTORY[-1], a2.WEALTH_HISTORY[-1]):
    avg = 0
    for z, w in zip(zw, ww):
        avg += z*w

    zs2.append(avg)

zs3 = []
for zw, ww in zip(a3.Z_HISTORY[-1], a3.WEALTH_HISTORY[-1]):
    avg = 0
    for z, w in zip(zw, ww):
        avg += z*w

    zs3.append(avg)
    
    
zs4 = []
for zw, ww in zip(a4.Z_HISTORY[-1], a4.WEALTH_HISTORY[-1]):
    avg = 0
    for z, w in zip(zw, ww):
        avg += z*w

    zs4.append(avg)
    
    
    
# plt.plot(atks0, '--', label='beta=0')
plt.plot(zs1, '-.', label='beta=.1')
plt.plot(zs2, ':', label='beta=.2')
plt.plot(zs3, '--', label='beta=.35')
plt.plot(zs4, '-', label='beta=.45')
plt.legend()
plt.title("Transaction Value vs Time without Knowledge of Adversary")
plt.xlabel('Time')
plt.ylabel('Transaction Value')
# Out:
# Text(0, 0.5, 'Transaction Value')

# %%
# attack prob vs time with adversary knowledge
a0 = open_file('data2/0a.pickle')
a1 = open_file('data2/1a.pickle')
a2 = open_file('data2/2a.pickle')
a3 = open_file('data2/35a.pickle')
a4 = open_file('data2/45a.pickle')


atks0 = a0.ATTACK_HISTORY[-1]
    
atks1 = a1.ATTACK_HISTORY[-1]

atks2 = a2.ATTACK_HISTORY[-1]

atks3 = a3.ATTACK_HISTORY[-1]

atks4 = a4.ATTACK_HISTORY[-1]

    
# plt.plot(atks0, '--', label='beta=0')
plt.ylim([-0.1,1.1])
plt.plot(atks1, '-.', label='beta=.1')
plt.plot(atks2, ':', label='beta=.2')
plt.plot(atks3, '--', label='beta=.35')
plt.plot(atks4, '-', label='beta=.45')
plt.legend()
plt.title("Attack Probability vs Time without Knowledge of Adversary")
plt.xlabel('Time')
plt.ylabel('Attack Probability')
# Out:
# Text(0, 0.5, 'Attack Probability')

# %%
# mining performance vs gamma actual
a0 = open_file('data3/0.pickle')
a1 = open_file('data3/1.pickle')
a2 = open_file('data3/2.pickle')
a3 = open_file('data3/3.pickle')
a4 = open_file('data3/5.pickle')


last_wealths = a0.WEALTH_HISTORY[-1]
avgs0 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs0.append(avg)
    
last_wealths = a1.WEALTH_HISTORY[-1]
avgs1 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs1.append(avg)

last_wealths = a2.WEALTH_HISTORY[-1]
avgs2 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs2.append(avg)
    
last_wealths = a3.WEALTH_HISTORY[-1]
avgs3 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs3.append(avg)
    
last_wealths = a4.WEALTH_HISTORY[-1]
avgs4 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs4.append(avg)
    
    
plt.plot(avgs0, '--', label='gamma=0')
plt.plot(avgs1, '-.', label='gamma=.1')
plt.plot(avgs2, ':', label='gamma=.2')
plt.plot(avgs3, '--', label='gamma=.3')
plt.plot(avgs4, '-', label='gamma=.4')
plt.legend()
plt.title("Mining Performance vs Time")
plt.xlabel('Time')
plt.ylabel('Wealth')
# Out:
# Text(0, 0.5, 'Wealth')

# %%
# mining performance vs adv strength actual FALSE
a0 = open_file('data4/0a.pickle')
a1 = open_file('data4/1a.pickle')
a2 = open_file('data4/2a.pickle')
a3 = open_file('data4/35a.pickle')
a4 = open_file('data4/45a.pickle')


last_wealths = a0.WEALTH_HISTORY[-1]
avgs0 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs0.append(avg)
    
last_wealths = a1.WEALTH_HISTORY[-1]
avgs1 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs1.append(avg)

last_wealths = a2.WEALTH_HISTORY[-1]
avgs2 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs2.append(avg)
    
last_wealths = a3.WEALTH_HISTORY[-1]
avgs3 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs3.append(avg)
    
last_wealths = a4.WEALTH_HISTORY[-1]
avgs4 = []
for last_wealth in last_wealths:
    avg = 0
    for i in range(len(last_wealth)):
        avg += i * last_wealth[i]
    avgs4.append(avg)
    
    
# plt.plot(avgs0, '--', label='No adv')
plt.plot(avgs1, '-.', label='beta=.1')
plt.plot(avgs2, ':', label='beta=.2')
plt.plot(avgs3, '--', label='beta=.35')
plt.plot(avgs4, '-', label='beta=.45')
plt.legend()
plt.title("Performance with False Knowledge of Adversary")
plt.xlabel('Time')
plt.ylabel('Wealth')
# Out:
# Text(0, 0.5, 'Wealth')
